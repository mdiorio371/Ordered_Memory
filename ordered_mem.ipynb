# %%
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
## defining the model
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision.models.resnet import ResNet, BasicBlock
from torchvision.datasets import MNIST
from tqdm.autonotebook import tqdm
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import inspect
import time
from torch import nn, optim
import torch
from torchvision.transforms import Compose, ToTensor, Normalize, Resize
from torch.nn import Linear, ReLU, CrossEntropyLoss, Sequential, Conv2d, MaxPool2d, Module, Softmax, BatchNorm2d, Dropout
from torch.utils.data import DataLoader
import numpy as np
# Out:
# /usr/local/lib/python3.6/dist-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
torch.__version__
# Out:
# '1.3.1'

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# Only run download from github once

# %%
# !git clone https://github.com/yikangshen/Ordered-Memory.git

# %%
# %cd 'gdrive/My Drive/Colab Notebooks/Ordered-Memory-master'
# Out:
# /content/gdrive/My Drive/Colab Notebooks/Ordered-Memory-master

# %% [markdown]
# the data was changed to 5d

# %%
# !pwd
# !python listops.py --cuda --epochs 100
# Out:
# /content/gdrive/My Drive/Colab Notebooks/Ordered-Memory-master
# In fixed vocabulary mode. Training embeddings from scratch.
# Preprocessing training data.
# TOTAL PARAMS: 448523
# Args: Namespace(batch_size=128, batch_size_test=128, bidirection=False, clip=1.0, cuda=True, data='./data/listops', dropout=0.1, dropouti=0.1, dropoutm=0.3, dropouto=0.2, emsize=128, epochs=100, log_interval=100, lr=0.001, name='15763091737405753.pt', nhid=128, ninp=128, no_smart_batching=False, no_use_peano=False, nout=10, nslot=21, ntoken=20, padding_idx=0, philly=False, seed=1111, seq_len=100, seq_len_test=1000, smart_batching=True, std=False, test_only=False, use_peano=True, wdecay=1.2e-06)
# Model total parameters: 448523
# | epoch   1 |   100/   150 batches | lr 0.00100 | ms/batch 305.78 | loss  1.84 | acc 0.37
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 52.04s | test acc: 0.5941 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch   2 |   100/   150 batches | lr 0.00100 | ms/batch 280.92 | loss  1.14 | acc 0.61
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 52.38s | test acc: 0.6347 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch   3 |   100/   150 batches | lr 0.00100 | ms/batch 305.97 | loss  1.03 | acc 0.64
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 52.15s | test acc: 0.6478 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch   4 |   100/   150 batches | lr 0.00100 | ms/batch 304.55 | loss  0.96 | acc 0.65
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 51.99s | test acc: 0.6635 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch   5 |   100/   150 batches | lr 0.00100 | ms/batch 290.85 | loss  0.90 | acc 0.67
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 52.40s | test acc: 0.6782 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch   6 |   100/   150 batches | lr 0.00100 | ms/batch 306.32 | loss  0.87 | acc 0.68
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 51.87s | test acc: 0.6923 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch   7 |   100/   150 batches | lr 0.00100 | ms/batch 314.87 | loss  0.85 | acc 0.69
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time: 51.75s | test acc: 0.6987 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch   8 |   100/   150 batches | lr 0.00100 | ms/batch 263.42 | loss  0.79 | acc 0.71
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time: 51.17s | test acc: 0.7021 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch   9 |   100/   150 batches | lr 0.00100 | ms/batch 300.98 | loss  0.78 | acc 0.71
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time: 50.05s | test acc: 0.7275 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  10 |   100/   150 batches | lr 0.00100 | ms/batch 275.71 | loss  0.72 | acc 0.73
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time: 46.44s | test acc: 0.7333 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  11 |   100/   150 batches | lr 0.00100 | ms/batch 275.15 | loss  0.69 | acc 0.74
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time: 45.68s | test acc: 0.7386 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  12 |   100/   150 batches | lr 0.00100 | ms/batch 277.76 | loss  0.70 | acc 0.74
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time: 45.33s | test acc: 0.7456 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  13 |   100/   150 batches | lr 0.00100 | ms/batch 251.43 | loss  0.66 | acc 0.75
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time: 44.98s | test acc: 0.7490 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  14 |   100/   150 batches | lr 0.00100 | ms/batch 271.22 | loss  0.65 | acc 0.76
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time: 44.97s | test acc: 0.7490 |
#
# -----------------------------------------------------------------------------------------
# | epoch  15 |   100/   150 batches | lr 0.00100 | ms/batch 267.26 | loss  0.64 | acc 0.76
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time: 44.96s | test acc: 0.7418 |
#
# -----------------------------------------------------------------------------------------
# | epoch  16 |   100/   150 batches | lr 0.00100 | ms/batch 271.92 | loss  0.61 | acc 0.77
# -----------------------------------------------------------------------------------------
# | end of epoch  16 | time: 45.26s | test acc: 0.7520 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  17 |   100/   150 batches | lr 0.00100 | ms/batch 255.57 | loss  0.62 | acc 0.77
# -----------------------------------------------------------------------------------------
# | end of epoch  17 | time: 45.20s | test acc: 0.7500 |
#
# -----------------------------------------------------------------------------------------
# | epoch  18 |   100/   150 batches | lr 0.00100 | ms/batch 250.06 | loss  0.62 | acc 0.77
# -----------------------------------------------------------------------------------------
# | end of epoch  18 | time: 44.38s | test acc: 0.7552 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  19 |   100/   150 batches | lr 0.00100 | ms/batch 260.20 | loss  0.60 | acc 0.77
# -----------------------------------------------------------------------------------------
# | end of epoch  19 | time: 44.53s | test acc: 0.7571 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  20 |   100/   150 batches | lr 0.00100 | ms/batch 271.82 | loss  0.58 | acc 0.78
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time: 43.96s | test acc: 0.7573 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  21 |   100/   150 batches | lr 0.00100 | ms/batch 261.73 | loss  0.58 | acc 0.78
# -----------------------------------------------------------------------------------------
# | end of epoch  21 | time: 44.63s | test acc: 0.7561 |
#
# -----------------------------------------------------------------------------------------
# | epoch  22 |   100/   150 batches | lr 0.00100 | ms/batch 245.44 | loss  0.55 | acc 0.79
# -----------------------------------------------------------------------------------------
# | end of epoch  22 | time: 44.22s | test acc: 0.7602 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  23 |   100/   150 batches | lr 0.00100 | ms/batch 249.70 | loss  0.56 | acc 0.79
# -----------------------------------------------------------------------------------------
# | end of epoch  23 | time: 43.78s | test acc: 0.7663 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  24 |   100/   150 batches | lr 0.00100 | ms/batch 258.43 | loss  0.55 | acc 0.79
# -----------------------------------------------------------------------------------------
# | end of epoch  24 | time: 43.84s | test acc: 0.7697 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  25 |   100/   150 batches | lr 0.00100 | ms/batch 250.60 | loss  0.53 | acc 0.80
# -----------------------------------------------------------------------------------------
# | end of epoch  25 | time: 44.04s | test acc: 0.7576 |
#
# -----------------------------------------------------------------------------------------
# | epoch  26 |   100/   150 batches | lr 0.00100 | ms/batch 249.99 | loss  0.53 | acc 0.80
# -----------------------------------------------------------------------------------------
# | end of epoch  26 | time: 43.28s | test acc: 0.7703 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  27 |   100/   150 batches | lr 0.00100 | ms/batch 248.11 | loss  0.54 | acc 0.80
# -----------------------------------------------------------------------------------------
# | end of epoch  27 | time: 42.97s | test acc: 0.7731 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  28 |   100/   150 batches | lr 0.00100 | ms/batch 251.34 | loss  0.52 | acc 0.81
# -----------------------------------------------------------------------------------------
# | end of epoch  28 | time: 43.60s | test acc: 0.7764 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  29 |   100/   150 batches | lr 0.00100 | ms/batch 229.70 | loss  0.51 | acc 0.81
# -----------------------------------------------------------------------------------------
# | end of epoch  29 | time: 43.08s | test acc: 0.7783 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  30 |   100/   150 batches | lr 0.00100 | ms/batch 242.01 | loss  0.50 | acc 0.82
# -----------------------------------------------------------------------------------------
# | end of epoch  30 | time: 42.97s | test acc: 0.7847 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  31 |   100/   150 batches | lr 0.00100 | ms/batch 242.57 | loss  0.48 | acc 0.82
# -----------------------------------------------------------------------------------------
# | end of epoch  31 | time: 42.43s | test acc: 0.8109 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  32 |   100/   150 batches | lr 0.00100 | ms/batch 239.39 | loss  0.42 | acc 0.85
# -----------------------------------------------------------------------------------------
# | end of epoch  32 | time: 43.02s | test acc: 0.8352 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  33 |   100/   150 batches | lr 0.00100 | ms/batch 241.45 | loss  0.38 | acc 0.86
# -----------------------------------------------------------------------------------------
# | end of epoch  33 | time: 43.22s | test acc: 0.8573 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  34 |   100/   150 batches | lr 0.00100 | ms/batch 237.18 | loss  0.35 | acc 0.87
# -----------------------------------------------------------------------------------------
# | end of epoch  34 | time: 42.78s | test acc: 0.8638 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  35 |   100/   150 batches | lr 0.00100 | ms/batch 232.93 | loss  0.31 | acc 0.89
# -----------------------------------------------------------------------------------------
# | end of epoch  35 | time: 42.23s | test acc: 0.8823 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  36 |   100/   150 batches | lr 0.00100 | ms/batch 241.48 | loss  0.29 | acc 0.90
# -----------------------------------------------------------------------------------------
# | end of epoch  36 | time: 41.78s | test acc: 0.8849 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  37 |   100/   150 batches | lr 0.00100 | ms/batch 233.70 | loss  0.27 | acc 0.90
# -----------------------------------------------------------------------------------------
# | end of epoch  37 | time: 41.18s | test acc: 0.9039 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  38 |   100/   150 batches | lr 0.00100 | ms/batch 233.40 | loss  0.24 | acc 0.92
# -----------------------------------------------------------------------------------------
# | end of epoch  38 | time: 41.17s | test acc: 0.9140 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  39 |   100/   150 batches | lr 0.00100 | ms/batch 237.68 | loss  0.23 | acc 0.93
# -----------------------------------------------------------------------------------------
# | end of epoch  39 | time: 40.89s | test acc: 0.9078 |
#
# -----------------------------------------------------------------------------------------
# | epoch  40 |   100/   150 batches | lr 0.00100 | ms/batch 224.94 | loss  0.20 | acc 0.94
# -----------------------------------------------------------------------------------------
# | end of epoch  40 | time: 41.02s | test acc: 0.9169 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  41 |   100/   150 batches | lr 0.00100 | ms/batch 260.02 | loss  0.20 | acc 0.94
# -----------------------------------------------------------------------------------------
# | end of epoch  41 | time: 42.47s | test acc: 0.9234 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  42 |   100/   150 batches | lr 0.00100 | ms/batch 238.48 | loss  0.18 | acc 0.94
# -----------------------------------------------------------------------------------------
# | end of epoch  42 | time: 40.71s | test acc: 0.9243 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  43 |   100/   150 batches | lr 0.00100 | ms/batch 220.80 | loss  0.16 | acc 0.95
# -----------------------------------------------------------------------------------------
# | end of epoch  43 | time: 40.68s | test acc: 0.9287 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  44 |   100/   150 batches | lr 0.00100 | ms/batch 235.52 | loss  0.15 | acc 0.95
# -----------------------------------------------------------------------------------------
# | end of epoch  44 | time: 40.98s | test acc: 0.9313 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  45 |   100/   150 batches | lr 0.00100 | ms/batch 241.09 | loss  0.15 | acc 0.95
# -----------------------------------------------------------------------------------------
# | end of epoch  45 | time: 40.64s | test acc: 0.9300 |
#
# -----------------------------------------------------------------------------------------
# | epoch  46 |   100/   150 batches | lr 0.00100 | ms/batch 225.81 | loss  0.14 | acc 0.96
# -----------------------------------------------------------------------------------------
# | end of epoch  46 | time: 40.38s | test acc: 0.9346 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  47 |   100/   150 batches | lr 0.00100 | ms/batch 240.67 | loss  0.14 | acc 0.96
# -----------------------------------------------------------------------------------------
# | end of epoch  47 | time: 40.52s | test acc: 0.9373 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  48 |   100/   150 batches | lr 0.00100 | ms/batch 236.91 | loss  0.14 | acc 0.96
# -----------------------------------------------------------------------------------------
# | end of epoch  48 | time: 40.73s | test acc: 0.9346 |
#
# -----------------------------------------------------------------------------------------
# | epoch  49 |   100/   150 batches | lr 0.00100 | ms/batch 226.32 | loss  0.12 | acc 0.96
# -----------------------------------------------------------------------------------------
# | end of epoch  49 | time: 40.74s | test acc: 0.9364 |
#
# -----------------------------------------------------------------------------------------
# | epoch  50 |   100/   150 batches | lr 0.00100 | ms/batch 224.96 | loss  0.13 | acc 0.96
# -----------------------------------------------------------------------------------------
# | end of epoch  50 | time: 40.16s | test acc: 0.9380 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  51 |   100/   150 batches | lr 0.00100 | ms/batch 227.78 | loss  0.25 | acc 0.93
# -----------------------------------------------------------------------------------------
# | end of epoch  51 | time: 41.28s | test acc: 0.9396 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  52 |   100/   150 batches | lr 0.00100 | ms/batch 221.65 | loss  0.12 | acc 0.97
# -----------------------------------------------------------------------------------------
# | end of epoch  52 | time: 40.45s | test acc: 0.9359 |
#
# -----------------------------------------------------------------------------------------
# | epoch  53 |   100/   150 batches | lr 0.00100 | ms/batch 211.60 | loss  0.12 | acc 0.97
# -----------------------------------------------------------------------------------------
# | end of epoch  53 | time: 40.46s | test acc: 0.9403 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  54 |   100/   150 batches | lr 0.00100 | ms/batch 223.48 | loss  0.10 | acc 0.97
# -----------------------------------------------------------------------------------------
# | end of epoch  54 | time: 39.95s | test acc: 0.9388 |
#
# -----------------------------------------------------------------------------------------
# | epoch  55 |   100/   150 batches | lr 0.00100 | ms/batch 212.40 | loss  0.10 | acc 0.97
# -----------------------------------------------------------------------------------------
# | end of epoch  55 | time: 40.18s | test acc: 0.9436 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  56 |   100/   150 batches | lr 0.00100 | ms/batch 220.91 | loss  0.11 | acc 0.97
# -----------------------------------------------------------------------------------------
# | end of epoch  56 | time: 39.95s | test acc: 0.9481 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  57 |   100/   150 batches | lr 0.00100 | ms/batch 233.29 | loss  0.10 | acc 0.97
# -----------------------------------------------------------------------------------------
# | end of epoch  57 | time: 39.75s | test acc: 0.9444 |
#
# -----------------------------------------------------------------------------------------
# | epoch  58 |   100/   150 batches | lr 0.00100 | ms/batch 219.77 | loss  0.09 | acc 0.98
# -----------------------------------------------------------------------------------------
# | end of epoch  58 | time: 39.39s | test acc: 0.9463 |
#
# -----------------------------------------------------------------------------------------
# | epoch  59 |   100/   150 batches | lr 0.00100 | ms/batch 220.66 | loss  0.09 | acc 0.98
# -----------------------------------------------------------------------------------------
# | end of epoch  59 | time: 40.03s | test acc: 0.9471 |
#
# -----------------------------------------------------------------------------------------
# | epoch  60 |   100/   150 batches | lr 0.00050 | ms/batch 220.47 | loss  0.07 | acc 0.98
# -----------------------------------------------------------------------------------------
# | end of epoch  60 | time: 39.56s | test acc: 0.9564 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  61 |   100/   150 batches | lr 0.00050 | ms/batch 223.42 | loss  0.06 | acc 0.99
# -----------------------------------------------------------------------------------------
# | end of epoch  61 | time: 39.44s | test acc: 0.9580 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  62 |   100/   150 batches | lr 0.00050 | ms/batch 210.13 | loss  0.05 | acc 0.99
# -----------------------------------------------------------------------------------------
# | end of epoch  62 | time: 39.63s | test acc: 0.9582 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  63 |   100/   150 batches | lr 0.00050 | ms/batch 222.27 | loss  0.05 | acc 0.99
# -----------------------------------------------------------------------------------------
# | end of epoch  63 | time: 39.56s | test acc: 0.9592 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  64 |   100/   150 batches | lr 0.00050 | ms/batch 223.13 | loss  0.05 | acc 0.99
# -----------------------------------------------------------------------------------------
# | end of epoch  64 | time: 39.19s | test acc: 0.9597 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  65 |   100/   150 batches | lr 0.00050 | ms/batch 212.59 | loss  0.05 | acc 0.99
# -----------------------------------------------------------------------------------------
# | end of epoch  65 | time: 39.24s | test acc: 0.9646 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  66 |   100/   150 batches | lr 0.00050 | ms/batch 227.82 | loss  0.04 | acc 1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  66 | time: 39.35s | test acc: 0.9635 |
#
# -----------------------------------------------------------------------------------------
# | epoch  67 |   100/   150 batches | lr 0.00050 | ms/batch 195.39 | loss  0.04 | acc 1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  67 | time: 39.15s | test acc: 0.9623 |
#
# -----------------------------------------------------------------------------------------
# | epoch  68 |   100/   150 batches | lr 0.00050 | ms/batch 216.53 | loss  0.04 | acc 1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  68 | time: 39.24s | test acc: 0.9663 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  69 |   100/   150 batches | lr 0.00050 | ms/batch 224.68 | loss  0.04 | acc 1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  69 | time: 39.28s | test acc: 0.9661 |
#
# -----------------------------------------------------------------------------------------
# | epoch  70 |   100/   150 batches | lr 0.00050 | ms/batch 227.39 | loss  0.04 | acc 1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  70 | time: 39.74s | test acc: 0.9625 |
#
# -----------------------------------------------------------------------------------------
# | epoch  71 |   100/   150 batches | lr 0.00050 | ms/batch 216.81 | loss  0.06 | acc 0.99
# -----------------------------------------------------------------------------------------
# | end of epoch  71 | time: 39.68s | test acc: 0.9655 |
#
# -----------------------------------------------------------------------------------------
# | epoch  72 |   100/   150 batches | lr 0.00025 | ms/batch 232.56 | loss  0.04 | acc 1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  72 | time: 39.37s | test acc: 0.9718 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  73 |   100/   150 batches | lr 0.00025 | ms/batch 232.02 | loss  0.03 | acc 1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  73 | time: 39.32s | test acc: 0.9711 |
#
# -----------------------------------------------------------------------------------------
# | epoch  74 |   100/   150 batches | lr 0.00025 | ms/batch 216.46 | loss  0.03 | acc 1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  74 | time: 39.22s | test acc: 0.9712 |
#
# -----------------------------------------------------------------------------------------
# | epoch  75 |   100/   150 batches | lr 0.00025 | ms/batch 224.69 | loss  0.03 | acc 1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  75 | time: 39.23s | test acc: 0.9726 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  76 |   100/   150 batches | lr 0.00025 | ms/batch 222.91 | loss  0.02 | acc 1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  76 | time: 39.16s | test acc: 0.9713 |
#
# -----------------------------------------------------------------------------------------
# | epoch  77 |   100/   150 batches | lr 0.00025 | ms/batch 206.82 | loss  0.02 | acc 1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  77 | time: 38.77s | test acc: 0.9737 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  78 |   100/   150 batches | lr 0.00025 | ms/batch 230.15 | loss  0.02 | acc 1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  78 | time: 39.44s | test acc: 0.9751 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  79 |   100/   150 batches | lr 0.00025 | ms/batch 219.28 | loss  0.02 | acc 1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  79 | time: 39.54s | test acc: 0.9745 |
#
# -----------------------------------------------------------------------------------------
# | epoch  80 |   100/   150 batches | lr 0.00025 | ms/batch 230.73 | loss  0.02 | acc 1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  80 | time: 39.53s | test acc: 0.9740 |
#
# -----------------------------------------------------------------------------------------
# | epoch  81 |   100/   150 batches | lr 0.00025 | ms/batch 223.05 | loss  0.02 | acc 1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  81 | time: 40.02s | test acc: 0.9745 |
#
# -----------------------------------------------------------------------------------------
# | epoch  82 |   100/   150 batches | lr 0.00013 | ms/batch 217.55 | loss  0.02 | acc 1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  82 | time: 40.48s | test acc: 0.9758 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  83 |   100/   150 batches | lr 0.00013 | ms/batch 229.91 | loss  0.02 | acc 1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  83 | time: 40.82s | test acc: 0.9771 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  84 |   100/   150 batches | lr 0.00013 | ms/batch 233.01 | loss  0.01 | acc 1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  84 | time: 41.10s | test acc: 0.9771 |
#
# -----------------------------------------------------------------------------------------
# | epoch  85 |   100/   150 batches | lr 0.00013 | ms/batch 230.66 | loss  0.02 | acc 1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  85 | time: 41.02s | test acc: 0.9768 |
#
# -----------------------------------------------------------------------------------------
# | epoch  86 |   100/   150 batches | lr 0.00013 | ms/batch 231.94 | loss  0.02 | acc 1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  86 | time: 41.16s | test acc: 0.9761 |
#
# -----------------------------------------------------------------------------------------
# | epoch  87 |   100/   150 batches | lr 0.00006 | ms/batch 234.22 | loss  0.01 | acc 1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  87 | time: 39.75s | test acc: 0.9762 |
#
# -----------------------------------------------------------------------------------------
# | epoch  88 |   100/   150 batches | lr 0.00006 | ms/batch 223.53 | loss  0.01 | acc 1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  88 | time: 40.03s | test acc: 0.9767 |
#
# -----------------------------------------------------------------------------------------
# | epoch  89 |   100/   150 batches | lr 0.00006 | ms/batch 219.26 | loss  0.01 | acc 1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  89 | time: 41.39s | test acc: 0.9770 |
#
# -----------------------------------------------------------------------------------------
# | epoch  90 |   100/   150 batches | lr 0.00003 | ms/batch 238.89 | loss  0.01 | acc 1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  90 | time: 42.82s | test acc: 0.9767 |
#
# -----------------------------------------------------------------------------------------
# | epoch  91 |   100/   150 batches | lr 0.00003 | ms/batch 234.41 | loss  0.01 | acc 1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  91 | time: 41.50s | test acc: 0.9770 |
#
# -----------------------------------------------------------------------------------------
# | epoch  92 |   100/   150 batches | lr 0.00003 | ms/batch 237.20 | loss  0.01 | acc 1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  92 | time: 41.96s | test acc: 0.9768 |
#
# -----------------------------------------------------------------------------------------
# | epoch  93 |   100/   150 batches | lr 0.00002 | ms/batch 231.57 | loss  0.01 | acc 1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  93 | time: 42.18s | test acc: 0.9770 |
#
# -----------------------------------------------------------------------------------------
# | epoch  94 |   100/   150 batches | lr 0.00002 | ms/batch 234.90 | loss  0.01 | acc 1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  94 | time: 43.51s | test acc: 0.9773 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  95 |   100/   150 batches | lr 0.00002 | ms/batch 222.30 | loss  0.01 | acc 1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  95 | time: 42.94s | test acc: 0.9778 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  96 |   100/   150 batches | lr 0.00002 | ms/batch 249.56 | loss  0.01 | acc 1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  96 | time: 43.26s | test acc: 0.9780 |
#
# Saving model (new best validation)
# -----------------------------------------------------------------------------------------
# | epoch  97 |   100/   150 batches | lr 0.00002 | ms/batch 237.73 | loss  0.01 | acc 1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  97 | time: 41.48s | test acc: 0.9777 |
#
# -----------------------------------------------------------------------------------------
# | epoch  98 |   100/   150 batches | lr 0.00002 | ms/batch 221.73 | loss  0.01 | acc 1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  98 | time: 41.47s | test acc: 0.9774 |
#
# -----------------------------------------------------------------------------------------
# | epoch  99 |   100/   150 batches | lr 0.00002 | ms/batch 245.65 | loss  0.01 | acc 1.01
# -----------------------------------------------------------------------------------------
# | end of epoch  99 | time: 41.72s | test acc: 0.9775 |
#
# -----------------------------------------------------------------------------------------
# | epoch 100 |   100/   150 batches | lr 0.00001 | ms/batch 225.95 | loss  0.01 | acc 1.01
# -----------------------------------------------------------------------------------------
# | end of epoch 100 | time: 41.75s | test acc: 0.9773 |
#
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | test acc: 0.9780 |
